# %%
# This workbook is for exploring the data that will be used for the capstone excercise

#The data source is a from a project that I am part of at my work. The intention of the project is to analysis 
# historical data of certain product and software sales through various sales channels and the offers to 
#understand which once have helped gain a margin of more than 60%. 
#The analysis will help to understand which offers have been performing as per business expectations. 

# NOTE. : The data that I will leverage is a subset and is not the actual products or sale value.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action="ignore")

# %%
#Importing the dataset
df=pd.read_csv("data/Booking-Data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3309 entries, 0 to 3308
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Fiscal Quarter ID       3309 non-null   object
#  1   Product Classification  3309 non-null   object
#  2   Item Category           3309 non-null   object
#  3   Sales Channel Code      3309 non-null   object
#  4   Offer Level 1           3309 non-null   object
#  5   Offer Level 2           3309 non-null   object
#  6   Product Bookings Net    3309 non-null   float64
#  7   Product Standard Cost   3309 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 206.9+ KB

# %% [markdown]
# ## Description
# ##### Sale period
# Quarter when the sales were made
# ##### Product classification
# Classification of product as Hardware Vs Software
# ##### Item Category :
# Category of the item (Hardware Products, License, IOS Software, Subscription)
# ##### Sales Channel code
# Channel Code (End Customer, Distributor, Retailer)
# ##### Offer level 1
# Type of offer
# ##### Offer level 2
# Subcategory of the offer (What the customers see)
# ##### Bookings net
# Net booking value
# ##### Booking cost
# Cost of the offer

# %%
df.head()
# Out:
#   Fiscal Quarter ID Product Classification      Item Category  \
# 0         Quarter 1               Hardware  Hardware Products
# 1         Quarter 1               Hardware  Hardware Products
# 2         Quarter 1               Hardware  Hardware Products
# 3         Quarter 1               Hardware  Hardware Products
# 4         Quarter 1               Hardware  Hardware Products
#
#   Sales Channel Code       Offer Level 1          Offer Level 2  \
# 0        Distributor     Conference Room  Conference room Infra
# 1       END_CUSTOMER     Conference Room                Desktop
# 2            UNKNOWN  End Point solution             IoT Device
# 3       END_CUSTOMER  End Point solution             IoT Device
# 4        Distributor     Conference Room                Desktop
#
#    Product Bookings Net  Product Standard Cost
# 0          4.369957e+05           4.201881e+05
# 1          7.148818e+05           6.873863e+05
# 2          1.754371e+04           1.686895e+04
# 3          1.420321e+05           1.365693e+05
# 4          6.796322e+06           6.534925e+06

# %%
# rounding the net and cost values to 2 decimals
df = df.round({'Product Bookings Net': 2,'Product Standard Cost' : 2}) 
df.head()
# Out:
#   Fiscal Quarter ID Product Classification      Item Category  \
# 0         Quarter 1               Hardware  Hardware Products
# 1         Quarter 1               Hardware  Hardware Products
# 2         Quarter 1               Hardware  Hardware Products
# 3         Quarter 1               Hardware  Hardware Products
# 4         Quarter 1               Hardware  Hardware Products
#
#   Sales Channel Code       Offer Level 1          Offer Level 2  \
# 0        Distributor     Conference Room  Conference room Infra
# 1       END_CUSTOMER     Conference Room                Desktop
# 2            UNKNOWN  End Point solution             IoT Device
# 3       END_CUSTOMER  End Point solution             IoT Device
# 4        Distributor     Conference Room                Desktop
#
#    Product Bookings Net  Product Standard Cost
# 0             436995.66              420188.13
# 1             714881.78              687386.33
# 2              17543.71               16868.95
# 3             142032.06              136569.29
# 4            6796322.18             6534925.17

# %%
df.describe()
# Out:
#        Product Bookings Net  Product Standard Cost
# count          3.309000e+03           3.309000e+03
# mean           3.770823e+06           1.049653e+06
# std            2.074623e+07           9.688719e+06
# min            0.000000e+00           0.000000e+00
# 25%            1.606106e+04           5.705200e+02
# 50%            1.339477e+05           1.412635e+04
# 75%            1.168789e+06           1.898438e+05
# max            7.317185e+08           4.878123e+08

# %% [markdown]
# ##### Explore and understand the date. The visualization below will help understand the nature and distirbution of values for each feature

# %%
# check the distribution of Product classification
sns.countplot(x='Product Classification', data=df, label='Count')
# Out:
# <AxesSubplot:xlabel='Product Classification', ylabel='count'>

# %%
# check the Item Cateogry of Product classification
sns.countplot(x='Item Category', data=df, label='Count')
# Out:
# <AxesSubplot:xlabel='Item Category', ylabel='count'>

# %%
# check the distribution of Sales Channel Code
sns.countplot(x='Sales Channel Code', data=df, label='Count')
# Out:
# <AxesSubplot:xlabel='Sales Channel Code', ylabel='count'>

# %%
df['Offer Level 1'].value_counts()
# Out:
# End Point solution    1298
# Conference Room       1115
# Network Security       318
# Product One            300
# Others                 196
# Control Center          82
# Name: Offer Level 1, dtype: int64

# %%
df['Offer Level 2'].value_counts()
# Out:
# IoT Device                    525
# Security & Routing            383
# Desktop                       335
# Conference room Infra         286
# Screen Systems                272
# Security License              258
# License                       246
# Product One - Perpetual       244
# Non IOS Software              131
# Wireless License              130
# Switching License             105
# Security & Routing License    100
# Others                         64
# ASN-NG                         60
# Product One - Subscription     58
# Switch                         47
# Control Center console         35
# Contact Center License         30
# Name: Offer Level 2, dtype: int64

# %%
#Create Product Bookings Margin using Net & Cost 
df['Product Bookings Margin']=((df['Product Bookings Net']-df['Product Standard Cost'])
                               /df['Product Bookings Net']).replace(np.inf, 0)

# %%
# Mark the data with less than or equal to 60% margin as low margine and anything more as High Margin
df['High Margin'] = df['Product Bookings Margin'].apply(lambda x: 0 if x <=0.6 else 1 )

# %%
sns.countplot(x='High Margin', data=df, label='Count')
# Out:
# <AxesSubplot:xlabel='High Margin', ylabel='count'>

# %%
# check if there are any NULL values
df[df.isna().any(axis=1)]
# Out:
#      Fiscal Quarter ID Product Classification      Item Category  \
# 109          Quarter 1               Hardware  Hardware Products
# 110          Quarter 1               Software            License
# 192          Quarter 1               Hardware  Hardware Products
# 193          Quarter 1               Software            License
# 369          Quarter 1               Software            License
# 370          Quarter 1               Software            License
# 2313         Quarter 1               Software            License
# 2314         Quarter 1               Software            License
#
#      Sales Channel Code       Offer Level 1               Offer Level 2  \
# 109         Distributor  End Point solution          Security & Routing
# 110         Distributor  End Point solution  Security & Routing License
# 192         Distributor  End Point solution                      Switch
# 193         Distributor  End Point solution           Switching License
# 369        END_CUSTOMER  End Point solution            Wireless License
# 370        END_CUSTOMER  End Point solution            Wireless License
# 2313        Distributor  End Point solution            Wireless License
# 2314        Distributor  End Point solution            Wireless License
#
#       Product Bookings Net  Product Standard Cost  Product Bookings Margin  \
# 109                    0.0                    0.0                      NaN
# 110                    0.0                    0.0                      NaN
# 192                    0.0                    0.0                      NaN
# 193                    0.0                    0.0                      NaN
# 369                    0.0                    0.0                      NaN
# 370                    0.0                    0.0                      NaN
# 2313                   0.0                    0.0                      NaN
# 2314                   0.0                    0.0                      NaN
#
#       High Margin
# 109             1
# 110             1
# 192             1
# 193             1
# 369             1
# 370             1
# 2313            1
# 2314            1

# %%
# Delete rows with NaN 
Index_list = df.loc[pd.isna(df["Product Bookings Margin"]), :].index
df = df.drop(labels=Index_list,axis = 0)
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Fiscal Quarter ID, Product Classification, Item Category, Sales Channel Code, Offer Level 1, Offer Level 2, Product Bookings Net, Product Standard Cost, Product Bookings Margin, High Margin]
# Index: []

# %%
# Plot offer 2 by product classification to understand the distribution

OfferLevel1 = df['Offer Level 1'].unique()

cnt = len(pd.unique(df['Offer Level 1']))

fig, axes = plt.subplots(cnt, 2, figsize=(20, 10))

ind_x = 0
ind_y = 0

axes[0, 0].set_title("Product Classification - Hardware")
axes[0, 1].set_title("Product Classification - Software")

for value in OfferLevel1:
     sns.countplot(ax=axes[ind_x,ind_y], 
                   x='Offer Level 2', 
                   data=df[(df["Offer Level 1"] == value) & (df["Product Classification"] == "Hardware")],
                   label='Count')
     ind_y = ind_y + 1
     sns.countplot(ax=axes[ind_x,ind_y], 
                   x='Offer Level 2', 
                   data=df[(df["Offer Level 1"] == value) & (df["Product Classification"] == "Software")],
                   label='Count')
     ind_x = ind_x+1
     ind_y = 0

# %%
#Drop the columns which are not needed for modeling.
# Fiscal quater will not infulence the product manrgin since the data is just for one quarter
# Item category is not needed cause the sale is tied to offer level 2 
#Product booking net, cost are not needed since we have computed the product margin based on these values
df=df.drop(columns=['Fiscal Quarter ID','Item Category','Product Bookings Net',
                    'Product Standard Cost','Product Bookings Margin']) 

df.head()
# Out:
#   Product Classification Sales Channel Code       Offer Level 1  \
# 0               Hardware        Distributor     Conference Room
# 1               Hardware       END_CUSTOMER     Conference Room
# 2               Hardware            UNKNOWN  End Point solution
# 3               Hardware       END_CUSTOMER  End Point solution
# 4               Hardware        Distributor     Conference Room
#
#            Offer Level 2  High Margin
# 0  Conference room Infra            0
# 1                Desktop            0
# 2             IoT Device            0
# 3             IoT Device            0
# 4                Desktop            0

# %%
# convert the categorical features to numirical
df1 = pd.get_dummies(df) 
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3301 entries, 0 to 3308
# Data columns (total 31 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   High Margin                               3301 non-null   int64
#  1   Product Classification_Hardware           3301 non-null   uint8
#  2   Product Classification_Software           3301 non-null   uint8
#  3   Sales Channel Code_Distributor            3301 non-null   uint8
#  4   Sales Channel Code_END_CUSTOMER           3301 non-null   uint8
#  5   Sales Channel Code_Service Provider       3301 non-null   uint8
#  6   Sales Channel Code_UNKNOWN                3301 non-null   uint8
#  7   Offer Level 1_Conference Room             3301 non-null   uint8
#  8   Offer Level 1_Control Center              3301 non-null   uint8
#  9   Offer Level 1_End Point solution          3301 non-null   uint8
#  10  Offer Level 1_Network Security            3301 non-null   uint8
#  11  Offer Level 1_Others                      3301 non-null   uint8
#  12  Offer Level 1_Product One                 3301 non-null   uint8
#  13  Offer Level 2_ASN-NG                      3301 non-null   uint8
#  14  Offer Level 2_Conference room Infra       3301 non-null   uint8
#  15  Offer Level 2_Contact Center License      3301 non-null   uint8
#  16  Offer Level 2_Control Center console      3301 non-null   uint8
#  17  Offer Level 2_Desktop                     3301 non-null   uint8
#  18  Offer Level 2_IoT Device                  3301 non-null   uint8
#  19  Offer Level 2_License                     3301 non-null   uint8
#  20  Offer Level 2_Non IOS Software            3301 non-null   uint8
#  21  Offer Level 2_Others                      3301 non-null   uint8
#  22  Offer Level 2_Product One - Perpetual     3301 non-null   uint8
#  23  Offer Level 2_Product One - Subscription  3301 non-null   uint8
#  24  Offer Level 2_Screen Systems              3301 non-null   uint8
#  25  Offer Level 2_Security & Routing          3301 non-null   uint8
#  26  Offer Level 2_Security & Routing License  3301 non-null   uint8
#  27  Offer Level 2_Security License            3301 non-null   uint8
#  28  Offer Level 2_Switch                      3301 non-null   uint8
#  29  Offer Level 2_Switching License           3301 non-null   uint8
#  30  Offer Level 2_Wireless License            3301 non-null   uint8
# dtypes: int64(1), uint8(30)
# memory usage: 148.3 KB

# %%
# Identify the correlation among the features 
plt.figure(figsize=(20,10))
sns.heatmap(data=df1.corr(), annot=True, cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
# couple of level 1 and level 2 offers have strong correlation among themself
# likes Offer level 1 - Network security and level 2 corresponding license
# Product one and perpetual Hardware
# Software in general seems to have better corrrelation with the offers including Margin
# will leverage this data to run the modeles.

# %% [markdown]
# ## Create Training and Test data

# %%
X=df.drop('High Margin',axis = 1)

# %%
y=df['High Margin']

# %%
# Get Dummies
X = pd.get_dummies(X)
y = pd.get_dummies(y)

# %%
print(X.columns)
print(y.columns)
# Out:
# Index(['Product Classification_Hardware', 'Product Classification_Software',
#        'Sales Channel Code_Distributor', 'Sales Channel Code_END_CUSTOMER',
#        'Sales Channel Code_Service Provider', 'Sales Channel Code_UNKNOWN',
#        'Offer Level 1_Conference Room', 'Offer Level 1_Control Center',
#        'Offer Level 1_End Point solution', 'Offer Level 1_Network Security',
#        'Offer Level 1_Others', 'Offer Level 1_Product One',
#        'Offer Level 2_ASN-NG', 'Offer Level 2_Conference room Infra',
#        'Offer Level 2_Contact Center License',
#        'Offer Level 2_Control Center console', 'Offer Level 2_Desktop',
#        'Offer Level 2_IoT Device', 'Offer Level 2_License',
#        'Offer Level 2_Non IOS Software', 'Offer Level 2_Others',
#        'Offer Level 2_Product One - Perpetual',
#        'Offer Level 2_Product One - Subscription',
#        'Offer Level 2_Screen Systems', 'Offer Level 2_Security & Routing',
#        'Offer Level 2_Security & Routing License',
#        'Offer Level 2_Security License', 'Offer Level 2_Switch',
#        'Offer Level 2_Switching License', 'Offer Level 2_Wireless License'],
#       dtype='object')
# Int64Index([0, 1], dtype='int64')

# %%
y
# Out:
#       0  1
# 0     1  0
# 1     1  0
# 2     1  0
# 3     1  0
# 4     1  0
# ...  .. ..
# 3304  0  1
# 3305  0  1
# 3306  0  1
# 3307  0  1
# 3308  0  1
#
# [3301 rows x 2 columns]

# %%
# Avoid dummy trap. 
y = y.drop([0], axis=1)

# %%
y
# Out:
#       1
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 3304  1
# 3305  1
# 3306  1
# 3307  1
# 3308  1
#
# [3301 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,
                                               y,
                                               test_size=0.33,
                                               random_state=1)

print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (2211, 30) (1090, 30) (2211, 1) (1090, 1)

# %%
#Normalizing the data 
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
X_train_sc = pd.DataFrame(sc.fit_transform(X_train))
X_test_sc = pd.DataFrame(sc.transform(X_test))

# restore the feature name
X_train_sc.columns = X_train.columns.values
X_test_sc.columns = X_test.columns.values

# restore the row index
X_train_sc.index = X_train.index.values
X_test_sc.index = X_test.index.values

X_train = X_train_sc
X_test = X_test_sc

# %%
X_train
# Out:
#       Product Classification_Hardware  Product Classification_Software  \
# 1227                         0.707826                        -0.707826
# 1971                        -1.412776                         1.412776
# 1656                         0.707826                        -0.707826
# 134                          0.707826                        -0.707826
# 420                          0.707826                        -0.707826
# ...                               ...                              ...
# 2771                        -1.412776                         1.412776
# 911                          0.707826                        -0.707826
# 1102                         0.707826                        -0.707826
# 239                          0.707826                        -0.707826
# 1067                         0.707826                        -0.707826
#
#       Sales Channel Code_Distributor  Sales Channel Code_END_CUSTOMER  \
# 1227                       -1.052484                        -0.427768
# 1971                       -1.052484                         2.337715
# 1656                        0.950134                        -0.427768
# 134                        -1.052484                        -0.427768
# 420                        -1.052484                        -0.427768
# ...                              ...                              ...
# 2771                        0.950134                        -0.427768
# 911                        -1.052484                        -0.427768
# 1102                        0.950134                        -0.427768
# 239                         0.950134                        -0.427768
# 1067                        0.950134                        -0.427768
#
#       Sales Channel Code_Service Provider  Sales Channel Code_UNKNOWN  \
# 1227                             1.932479                   -0.348949
# 1971                            -0.517470                   -0.348949
# 1656                            -0.517470                   -0.348949
# 134                             -0.517470                    2.865746
# 420                              1.932479                   -0.348949
# ...                                   ...                         ...
# 2771                            -0.517470                   -0.348949
# 911                              1.932479                   -0.348949
# 1102                            -0.517470                   -0.348949
# 239                             -0.517470                   -0.348949
# 1067                            -0.517470                   -0.348949
#
#       Offer Level 1_Conference Room  Offer Level 1_Control Center  \
# 1227                      -0.718652                     -0.164132
# 1971                       1.391494                     -0.164132
# 1656                      -0.718652                     -0.164132
# 134                       -0.718652                     -0.164132
# 420                       -0.718652                     -0.164132
# ...                             ...                           ...
# 2771                      -0.718652                     -0.164132
# 911                       -0.718652                     -0.164132
# 1102                      -0.718652                     -0.164132
# 239                        1.391494                     -0.164132
# 1067                      -0.718652                      6.092675
#
#       Offer Level 1_End Point solution  Offer Level 1_Network Security  ...  \
# 1227                          1.261756                       -0.332411  ...
# 1971                         -0.792546                       -0.332411  ...
# 1656                          1.261756                       -0.332411  ...
# 134                           1.261756                       -0.332411  ...
# 420                          -0.792546                       -0.332411  ...
# ...                                ...                             ...  ...
# 2771                          1.261756                       -0.332411  ...
# 911                           1.261756                       -0.332411  ...
# 1102                          1.261756                       -0.332411  ...
# 239                          -0.792546                       -0.332411  ...
# 1067                         -0.792546                       -0.332411  ...
#
#       Offer Level 2_Others  Offer Level 2_Product One - Perpetual  \
# 1227             -0.139154                              -0.275522
# 1971             -0.139154                              -0.275522
# 1656             -0.139154                              -0.275522
# 134              -0.139154                              -0.275522
# 420              -0.139154                               3.629473
# ...                    ...                                    ...
# 2771             -0.139154                              -0.275522
# 911              -0.139154                              -0.275522
# 1102             -0.139154                              -0.275522
# 239              -0.139154                               3.629473
# 1067             -0.139154                              -0.275522
#
#       Offer Level 2_Product One - Subscription  Offer Level 2_Screen Systems  \
# 1227                                 -0.137455                     -0.300394
# 1971                                 -0.137455                     -0.300394
# 1656                                 -0.137455                     -0.300394
# 134                                  -0.137455                     -0.300394
# 420                                  -0.137455                     -0.300394
# ...                                        ...                           ...
# 2771                                 -0.137455                     -0.300394
# 911                                  -0.137455                     -0.300394
# 1102                                 -0.137455                     -0.300394
# 239                                  -0.137455                     -0.300394
# 1067                                 -0.137455                     -0.300394
#
#       Offer Level 2_Security & Routing  \
# 1227                          2.775739
# 1971                         -0.360264
# 1656                         -0.360264
# 134                          -0.360264
# 420                          -0.360264
# ...                                ...
# 2771                         -0.360264
# 911                          -0.360264
# 1102                          2.775739
# 239                          -0.360264
# 1067                         -0.360264
#
#       Offer Level 2_Security & Routing License  \
# 1227                                 -0.180818
# 1971                                 -0.180818
# 1656                                 -0.180818
# 134                                  -0.180818
# 420                                  -0.180818
# ...                                        ...
# 2771                                  5.530435
# 911                                  -0.180818
# 1102                                 -0.180818
# 239                                  -0.180818
# 1067                                 -0.180818
#
#       Offer Level 2_Security License  Offer Level 2_Switch  \
# 1227                       -0.300394             -0.115285
# 1971                       -0.300394             -0.115285
# 1656                       -0.300394             -0.115285
# 134                        -0.300394             -0.115285
# 420                        -0.300394             -0.115285
# ...                              ...                   ...
# 2771                       -0.300394             -0.115285
# 911                        -0.300394             -0.115285
# 1102                       -0.300394             -0.115285
# 239                        -0.300394             -0.115285
# 1067                       -0.300394             -0.115285
#
#       Offer Level 2_Switching License  Offer Level 2_Wireless License
# 1227                        -0.178133                       -0.193755
# 1971                        -0.178133                       -0.193755
# 1656                        -0.178133                       -0.193755
# 134                         -0.178133                       -0.193755
# 420                         -0.178133                       -0.193755
# ...                               ...                             ...
# 2771                        -0.178133                       -0.193755
# 911                         -0.178133                       -0.193755
# 1102                        -0.178133                       -0.193755
# 239                         -0.178133                       -0.193755
# 1067                        -0.178133                       -0.193755
#
# [2211 rows x 30 columns]

# %%
X_train=X_train.values
X_test=X_test.values
y_train=y_train.values
y_test=y_test.values

# %% [markdown]
# ## Build and Compare models

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
# Generate the decision tree on the base data to look at offer distribution based on Margin classification
clf = DecisionTreeClassifier(criterion='entropy',random_state=0)
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
fig, axe = plt.subplots(figsize=(40,40))

tree.plot_tree(clf,
               feature_names=list(X.columns),
               class_names=['Low Margin','High Margin'],
               ax = axe,
               filled=True,
               precision=2,
               node_ids=True,
               fontsize=18,
               label='root',
               proportion=False,
               #proportion=True,
               impurity=True)
# Out:
# [Text(1493.032774390244, 2090.769230769231, 'node #0\nProduct Classification_Hardware <= 0.5\nentropy = 0.87\nsamples = 3301\nvalue = [959, 2342]\nclass = High Margin'),
#  Text(1044.123475609756, 1923.5076923076924, '#1\nOffer Level 2_Wireless License <= 0.5\n0.45\n1052\n[99, 953]\nHigh Margin'),
#  Text(890.5884146341464, 1756.246153846154, '#2\nOffer Level 2_Contact Center License <= 0.5\n0.39\n926\n[72, 854]\nHigh Margin'),
#  Text(719.6158536585366, 1588.9846153846156, '#3\nOffer Level 2_Security License <= 0.5\n0.37\n896\n[64, 832]\nHigh Margin'),
#  Text(513.7682926829268, 1421.7230769230769, '#4\nOffer Level 2_Non IOS Software <= 0.5\n0.3\n638\n[34, 604]\nHigh Margin'),
#  Text(340.2439024390244, 1254.4615384615386, '#5\nSales Channel Code_Service Provider <= 0.5\n0.22\n507\n[18, 489]\nHigh Margin'),
#  Text(313.0243902439024, 1087.2, '#6\nSales Channel Code_UNKNOWN <= 0.5\n0.26\n420\n[18, 402]\nHigh Margin'),
#  Text(217.7560975609756, 919.9384615384615, '#7\nOffer Level 2_Product One - Subscription <= 0.5\n0.23\n377\n[14, 363]\nHigh Margin'),
#  Text(190.53658536585365, 752.6769230769232, '#8\nOffer Level 2_Security & Routing License <= 0.5\n0.25\n333\n[14, 319]\nHigh Margin'),
#  Text(136.09756097560975, 585.4153846153847, '#9\nOffer Level 1_Others <= 0.5\n0.29\n260\n[13, 247]\nHigh Margin'),
#  Text(108.8780487804878, 418.1538461538462, '#10\nSales Channel Code_Distributor <= 0.5\n0.3\n247\n[13, 234]\nHigh Margin'),
#  Text(54.4390243902439, 250.89230769230767, '#11\nOffer Level 2_License <= 0.5\n0.18\n37\n[1, 36]\nHigh Margin'),
#  Text(27.21951219512195, 83.63076923076915, '#12\n0.0\n11\n[0, 11]\nHigh Margin'),
#  Text(81.65853658536585, 83.63076923076915, '#13\n0.24\n26\n[1, 25]\nHigh Margin'),
#  Text(163.3170731707317, 250.89230769230767, '#14\nOffer Level 1_End Point solution <= 0.5\n0.32\n210\n[12, 198]\nHigh Margin'),
#  Text(136.09756097560975, 83.63076923076915, '#15\n0.31\n143\n[8, 135]\nHigh Margin'),
#  Text(190.53658536585365, 83.63076923076915, '#16\n0.33\n67\n[4, 63]\nHigh Margin'),
#  Text(163.3170731707317, 418.1538461538462, '#17\n0.0\n13\n[0, 13]\nHigh Margin'),
#  Text(244.97560975609755, 585.4153846153847, '#18\nSales Channel Code_Distributor <= 0.5\n0.1\n73\n[1, 72]\nHigh Margin'),
#  Text(217.7560975609756, 418.1538461538462, '#19\n0.5\n9\n[1, 8]\nHigh Margin'),
#  Text(272.1951219512195, 418.1538461538462, '#20\n0.0\n64\n[0, 64]\nHigh Margin'),
#  Text(244.97560975609755, 752.6769230769232, '#21\n0.0\n44\n[0, 44]\nHigh Margin'),
#  Text(408.29268292682923, 919.9384615384615, '#22\nOffer Level 2_Security & Routing License <= 0.5\n0.45\n43\n[4, 39]\nHigh Margin'),
#  Text(381.0731707317073, 752.6769230769232, '#23\nOffer Level 2_Product One - Subscription <= 0.5\n0.32\n34\n[2, 32]\nHigh Margin'),
#  Text(353.8536585365854, 585.4153846153847, '#24\nOffer Level 1_Conference Room <= 0.5\n0.23\n27\n[1, 26]\nHigh Margin'),
#  Text(326.6341463414634, 418.1538461538462, '#25\n0.0\n7\n[0, 7]\nHigh Margin'),
#  Text(381.0731707317073, 418.1538461538462, '#26\n0.29\n20\n[1, 19]\nHigh Margin'),
#  Text(408.29268292682923, 585.4153846153847, '#27\n0.59\n7\n[1, 6]\nHigh Margin'),
#  Text(435.5121951219512, 752.6769230769232, '#28\n0.76\n9\n[2, 7]\nHigh Margin'),
#  Text(367.4634146341463, 1087.2, '#29\n0.0\n87\n[0, 87]\nHigh Margin'),
#  Text(687.2926829268292, 1254.4615384615386, '#30\nSales Channel Code_Distributor <= 0.5\n0.54\n131\n[16, 115]\nHigh Margin'),
#  Text(612.4390243902438, 1087.2, '#31\nSales Channel Code_Service Provider <= 0.5\n0.64\n49\n[8, 41]\nHigh Margin'),
#  Text(544.390243902439, 919.9384615384615, '#32\nOffer Level 1_Control Center <= 0.5\n0.74\n24\n[5, 19]\nHigh Margin'),
#  Text(489.9512195121951, 752.6769230769232, '#33\nSales Channel Code_END_CUSTOMER <= 0.5\n0.7\n21\n[4, 17]\nHigh Margin'),
#  Text(462.7317073170732, 585.4153846153847, '#34\n0.54\n8\n[1, 7]\nHigh Margin'),
#  Text(517.170731707317, 585.4153846153847, '#35\n0.78\n13\n[3, 10]\nHigh Margin'),
#  Text(598.8292682926829, 752.6769230769232, '#36\nSales Channel Code_UNKNOWN <= 0.5\n0.92\n3\n[1, 2]\nHigh Margin'),
#  Text(571.609756097561, 585.4153846153847, '#37\n0.0\n1\n[0, 1]\nHigh Margin'),
#  Text(626.0487804878048, 585.4153846153847, '#38\n1.0\n2\n[1, 1]\nLow Margin'),
#  Text(680.4878048780488, 919.9384615384615, '#39\nOffer Level 1_Control Center <= 0.5\n0.53\n25\n[3, 22]\nHigh Margin'),
#  Text(653.2682926829268, 752.6769230769232, '#40\n0.56\n23\n[3, 20]\nHigh Margin'),
#  Text(707.7073170731708, 752.6769230769232, '#41\n0.0\n2\n[0, 2]\nHigh Margin'),
#  Text(762.1463414634146, 1087.2, '#42\nOffer Level 1_Others <= 0.5\n0.46\n82\n[8, 74]\nHigh Margin'),
#  Text(734.9268292682926, 919.9384615384615, '#43\n0.0\n12\n[0, 12]\nHigh Margin'),
#  Text(789.3658536585366, 919.9384615384615, '#44\n0.51\n70\n[8, 62]\nHigh Margin'),
#  Text(925.4634146341464, 1421.7230769230769, '#45\nSales Channel Code_Distributor <= 0.5\n0.52\n258\n[30, 228]\nHigh Margin'),
#  Text(898.2439024390244, 1254.4615384615386, '#46\nSales Channel Code_UNKNOWN <= 0.5\n0.64\n118\n[19, 99]\nHigh Margin'),
#  Text(871.0243902439024, 1087.2, '#47\nSales Channel Code_Service Provider <= 0.5\n0.69\n92\n[17, 75]\nHigh Margin'),
#  Text(843.8048780487804, 919.9384615384615, '#48\n0.76\n36\n[8, 28]\nHigh Margin'),
#  Text(898.2439024390244, 919.9384615384615, '#49\n0.64\n56\n[9, 47]\nHigh Margin'),
#  Text(925.4634146341464, 1087.2, '#50\n0.39\n26\n[2, 24]\nHigh Margin'),
#  Text(952.6829268292682, 1254.4615384615386, '#51\n0.4\n140\n[11, 129]\nHigh Margin'),
#  Text(1061.560975609756, 1588.9846153846156, '#52\nSales Channel Code_UNKNOWN <= 0.5\n0.84\n30\n[8, 22]\nHigh Margin'),
#  Text(1034.341463414634, 1421.7230769230769, '#53\nSales Channel Code_Service Provider <= 0.5\n0.76\n27\n[6, 21]\nHigh Margin'),
#  Text(1007.1219512195122, 1254.4615384615386, '#54\nSales Channel Code_Distributor <= 0.5\n0.79\n21\n[5, 16]\nHigh Margin'),
#  Text(979.9024390243902, 1087.2, '#55\n0.81\n4\n[1, 3]\nHigh Margin'),
#  Text(1034.341463414634, 1087.2, '#56\n0.79\n17\n[4, 13]\nHigh Margin'),
#  Text(1061.560975609756, 1254.4615384615386, '#57\n0.65\n6\n[1, 5]\nHigh Margin'),
#  Text(1088.780487804878, 1421.7230769230769, '#58\n0.92\n3\n[2, 1]\nLow Margin'),
#  Text(1197.6585365853657, 1756.246153846154, '#59\nSales Channel Code_UNKNOWN <= 0.5\n0.75\n126\n[27, 99]\nHigh Margin'),
#  Text(1170.439024390244, 1588.9846153846156, '#60\nSales Channel Code_END_CUSTOMER <= 0.5\n0.78\n116\n[27, 89]\nHigh Margin'),
#  Text(1143.219512195122, 1421.7230769230769, '#61\nSales Channel Code_Distributor <= 0.5\n0.71\n97\n[19, 78]\nHigh Margin'),
#  Text(1116.0, 1254.4615384615386, '#62\n0.78\n26\n[6, 20]\nHigh Margin'),
#  Text(1170.439024390244, 1254.4615384615386, '#63\n0.69\n71\n[13, 58]\nHigh Margin'),
#  Text(1197.6585365853657, 1421.7230769230769, '#64\n0.98\n19\n[8, 11]\nHigh Margin'),
#  Text(1224.8780487804877, 1588.9846153846156, '#65\n0.0\n10\n[0, 10]\nHigh Margin'),
#  Text(1941.9420731707316, 1923.5076923076924, '#66\nSales Channel Code_END_CUSTOMER <= 0.5\n0.96\n2249\n[860, 1389]\nHigh Margin'),
#  Text(1706.3231707317073, 1756.246153846154, '#67\nOffer Level 1_End Point solution <= 0.5\n0.92\n1860\n[626, 1234]\nHigh Margin'),
#  Text(1520.890243902439, 1588.9846153846156, '#68\nOffer Level 1_Control Center <= 0.5\n0.95\n1033\n[385, 648]\nHigh Margin'),
#  Text(1381.390243902439, 1421.7230769230769, '#69\nOffer Level 2_ASN-NG <= 0.5\n0.96\n1001\n[382, 619]\nHigh Margin'),
#  Text(1238.4878048780488, 1254.4615384615386, '#70\nSales Channel Code_UNKNOWN <= 0.5\n0.97\n949\n[374, 575]\nHigh Margin'),
#  Text(1088.780487804878, 1087.2, '#71\nOffer Level 1_Conference Room <= 0.5\n0.98\n812\n[332, 480]\nHigh Margin'),
#  Text(979.9024390243902, 919.9384615384615, '#72\nOffer Level 1_Product One <= 0.5\n1.0\n187\n[88, 99]\nHigh Margin'),
#  Text(925.4634146341464, 752.6769230769232, '#73\nSales Channel Code_Service Provider <= 0.5\n0.99\n11\n[6, 5]\nLow Margin'),
#  Text(898.2439024390244, 585.4153846153847, '#74\n0.97\n10\n[6, 4]\nLow Margin'),
#  Text(952.6829268292682, 585.4153846153847, '#75\n0.0\n1\n[0, 1]\nHigh Margin'),
#  Text(1034.341463414634, 752.6769230769232, '#76\nSales Channel Code_Distributor <= 0.5\n1.0\n176\n[82, 94]\nHigh Margin'),
#  Text(1007.1219512195122, 585.4153846153847, '#77\n0.99\n48\n[22, 26]\nHigh Margin'),
#  Text(1061.560975609756, 585.4153846153847, '#78\n1.0\n128\n[60, 68]\nHigh Margin'),
#  Text(1197.6585365853657, 919.9384615384615, '#79\nOffer Level 2_Product One - Perpetual <= 0.5\n0.97\n625\n[244, 381]\nHigh Margin'),
#  Text(1170.439024390244, 752.6769230769232, '#80\nSales Channel Code_Distributor <= 0.5\n0.96\n623\n[242, 381]\nHigh Margin'),
#  Text(1116.0, 585.4153846153847, '#81\nOffer Level 2_Screen Systems <= 0.5\n0.98\n193\n[82, 111]\nHigh Margin'),
#  Text(1088.780487804878, 418.1538461538462, '#82\nOffer Level 2_Desktop <= 0.5\n0.99\n129\n[58, 71]\nHigh Margin'),
#  Text(1061.560975609756, 250.89230769230767, '#83\n0.99\n66\n[29, 37]\nHigh Margin'),
#  Text(1116.0, 250.89230769230767, '#84\n1.0\n63\n[29, 34]\nHigh Margin'),
#  Text(1143.219512195122, 418.1538461538462, '#85\n0.95\n64\n[24, 40]\nHigh Margin'),
#  Text(1224.8780487804877, 585.4153846153847, '#86\nOffer Level 2_Conference room Infra <= 0.5\n0.95\n430\n[160, 270]\nHigh Margin'),
#  Text(1197.6585365853657, 418.1538461538462, '#87\nOffer Level 2_Desktop <= 0.5\n0.94\n296\n[105, 191]\nHigh Margin'),
#  Text(1170.439024390244, 250.89230769230767, '#88\n0.94\n127\n[46, 81]\nHigh Margin'),
#  Text(1224.8780487804877, 250.89230769230767, '#89\n0.93\n169\n[59, 110]\nHigh Margin'),
#  Text(1252.0975609756097, 418.1538461538462, '#90\n0.98\n134\n[55, 79]\nHigh Margin'),
#  Text(1224.8780487804877, 752.6769230769232, '#91\n0.0\n2\n[2, 0]\nLow Margin'),
#  Text(1388.1951219512196, 1087.2, '#92\nOffer Level 2_IoT Device <= 0.5\n0.89\n137\n[42, 95]\nHigh Margin'),
#  Text(1360.9756097560976, 919.9384615384615, '#93\nOffer Level 1_Conference Room <= 0.5\n0.88\n136\n[41, 95]\nHigh Margin'),
#  Text(1306.5365853658536, 752.6769230769232, '#94\nOffer Level 1_Others <= 0.5\n0.74\n29\n[6, 23]\nHigh Margin'),
#  Text(1279.3170731707316, 585.4153846153847, '#95\n0.76\n27\n[6, 21]\nHigh Margin'),
#  Text(1333.7560975609756, 585.4153846153847, '#96\n0.0\n2\n[0, 2]\nHigh Margin'),
#  Text(1415.4146341463415, 752.6769230769232, '#97\nOffer Level 2_Desktop <= 0.5\n0.91\n107\n[35, 72]\nHigh Margin'),
#  Text(1388.1951219512196, 585.4153846153847, '#98\nOffer Level 2_Conference room Infra <= 0.5\n0.88\n67\n[20, 47]\nHigh Margin'),
#  Text(1360.9756097560976, 418.1538461538462, '#99\n0.9\n35\n[11, 24]\nHigh Margin'),
#  Text(1415.4146341463415, 418.1538461538462, '#100\n0.86\n32\n[9, 23]\nHigh Margin'),
#  Text(1442.6341463414633, 585.4153846153847, '#101\n0.95\n40\n[15, 25]\nHigh Margin'),
#  Text(1415.4146341463415, 919.9384615384615, '#102\n0.0\n1\n[1, 0]\nLow Margin'),
#  Text(1524.2926829268292, 1254.4615384615386, '#103\nSales Channel Code_Service Provider <= 0.5\n0.62\n52\n[8, 44]\nHigh Margin'),
#  Text(1497.0731707317073, 1087.2, '#104\nSales Channel Code_UNKNOWN <= 0.5\n0.75\n37\n[8, 29]\nHigh Margin'),
#  Text(1469.8536585365853, 919.9384615384615, '#105\n0.8\n29\n[7, 22]\nHigh Margin'),
#  Text(1524.2926829268292, 919.9384615384615, '#106\n0.54\n8\n[1, 7]\nHigh Margin'),
#  Text(1551.5121951219512, 1087.2, '#107\n0.0\n15\n[0, 15]\nHigh Margin'),
#  Text(1660.390243902439, 1421.7230769230769, '#108\nSales Channel Code_UNKNOWN <= 0.5\n0.45\n32\n[3, 29]\nHigh Margin'),
#  Text(1633.170731707317, 1254.4615384615386, '#109\nSales Channel Code_Service Provider <= 0.5\n0.36\n29\n[2, 27]\nHigh Margin'),
#  Text(1605.9512195121952, 1087.2, '#110\n0.41\n24\n[2, 22]\nHigh Margin'),
#  Text(1660.390243902439, 1087.2, '#111\n0.0\n5\n[0, 5]\nHigh Margin'),
#  Text(1687.6097560975609, 1254.4615384615386, '#112\n0.92\n3\n[1, 2]\nHigh Margin'),
#  Text(1891.7560975609756, 1588.9846153846156, '#113\nSales Channel Code_Distributor <= 0.5\n0.87\n827\n[241, 586]\nHigh Margin'),
#  Text(1796.4878048780488, 1421.7230769230769, '#114\nSales Channel Code_Service Provider <= 0.5\n0.8\n349\n[85, 264]\nHigh Margin'),
#  Text(1742.0487804878048, 1254.4615384615386, '#115\nOffer Level 2_Switch <= 0.5\n0.73\n112\n[23, 89]\nHigh Margin'),
#  Text(1714.8292682926829, 1087.2, '#116\nOffer Level 2_Security & Routing <= 0.5\n0.75\n107\n[23, 84]\nHigh Margin'),
#  Text(1687.6097560975609, 919.9384615384615, '#117\nOffer Level 2_IoT Device <= 0.5\n0.7\n64\n[12, 52]\nHigh Margin'),
#  Text(1660.390243902439, 752.6769230769232, '#118\n0.0\n1\n[0, 1]\nHigh Margin'),
#  Text(1714.8292682926829, 752.6769230769232, '#119\n0.7\n63\n[12, 51]\nHigh Margin'),
#  Text(1742.0487804878048, 919.9384615384615, '#120\n0.82\n43\n[11, 32]\nHigh Margin'),
#  Text(1769.2682926829268, 1087.2, '#121\n0.0\n5\n[0, 5]\nHigh Margin'),
#  Text(1850.9268292682927, 1254.4615384615386, '#122\nOffer Level 2_Security & Routing <= 0.5\n0.83\n237\n[62, 175]\nHigh Margin'),
#  Text(1823.7073170731708, 1087.2, '#123\nOffer Level 2_Desktop <= 0.5\n0.86\n146\n[41, 105]\nHigh Margin'),
#  Text(1796.4878048780488, 919.9384615384615, '#124\nOffer Level 2_Switch <= 0.5\n0.85\n144\n[40, 104]\nHigh Margin'),
#  Text(1769.2682926829268, 752.6769230769232, '#125\n0.86\n131\n[37, 94]\nHigh Margin'),
#  Text(1823.7073170731708, 752.6769230769232, '#126\n0.78\n13\n[3, 10]\nHigh Margin'),
#  Text(1850.9268292682927, 919.9384615384615, '#127\n1.0\n2\n[1, 1]\nLow Margin'),
#  Text(1878.1463414634145, 1087.2, '#128\n0.78\n91\n[21, 70]\nHigh Margin'),
#  Text(1987.0243902439024, 1421.7230769230769, '#129\nOffer Level 2_Security & Routing <= 0.5\n0.91\n478\n[156, 322]\nHigh Margin'),
#  Text(1959.8048780487804, 1254.4615384615386, '#130\nOffer Level 2_Desktop <= 0.5\n0.87\n279\n[81, 198]\nHigh Margin'),
#  Text(1932.5853658536585, 1087.2, '#131\nOffer Level 2_IoT Device <= 0.5\n0.87\n275\n[81, 194]\nHigh Margin'),
#  Text(1905.3658536585365, 919.9384615384615, '#132\n0.85\n22\n[6, 16]\nHigh Margin'),
#  Text(1959.8048780487804, 919.9384615384615, '#133\n0.88\n253\n[75, 178]\nHigh Margin'),
#  Text(1987.0243902439024, 1087.2, '#134\n0.0\n4\n[0, 4]\nHigh Margin'),
#  Text(2014.2439024390244, 1254.4615384615386, '#135\n0.96\n199\n[75, 124]\nHigh Margin'),
#  Text(2177.560975609756, 1756.246153846154, '#136\nOffer Level 1_Others <= 0.5\n0.97\n389\n[234, 155]\nLow Margin'),
#  Text(2150.3414634146343, 1588.9846153846156, '#137\nOffer Level 2_Security & Routing <= 0.5\n1.0\n338\n[183, 155]\nLow Margin'),
#  Text(2123.121951219512, 1421.7230769230769, '#138\nOffer Level 2_ASN-NG <= 0.5\n1.0\n289\n[153, 136]\nLow Margin'),
#  Text(2095.9024390243903, 1254.4615384615386, '#139\nOffer Level 2_Conference room Infra <= 0.5\n1.0\n281\n[150, 131]\nLow Margin'),
#  Text(2068.682926829268, 1087.2, '#140\nOffer Level 1_Conference Room <= 0.5\n0.99\n227\n[124, 103]\nLow Margin'),
#  Text(2014.2439024390244, 919.9384615384615, '#141\nOffer Level 2_Control Center console <= 0.5\n1.0\n127\n[66, 61]\nLow Margin'),
#  Text(1987.0243902439024, 752.6769230769232, '#142\nOffer Level 2_IoT Device <= 0.5\n1.0\n124\n[65, 59]\nLow Margin'),
#  Text(1959.8048780487804, 585.4153846153847, '#143\nOffer Level 1_End Point solution <= 0.5\n1.0\n47\n[24, 23]\nLow Margin'),
#  Text(1932.5853658536585, 418.1538461538462, '#144\n1.0\n39\n[20, 19]\nLow Margin'),
#  Text(1987.0243902439024, 418.1538461538462, '#145\nOffer Level 2_Desktop <= 0.5\n1.0\n8\n[4, 4]\nLow Margin'),
#  Text(1959.8048780487804, 250.89230769230767, '#146\n1.0\n6\n[3, 3]\nLow Margin'),
#  Text(2014.2439024390244, 250.89230769230767, '#147\n1.0\n2\n[1, 1]\nLow Margin'),
#  Text(2014.2439024390244, 585.4153846153847, '#148\n1.0\n77\n[41, 36]\nLow Margin'),
#  Text(2041.4634146341464, 752.6769230769232, '#149\n0.92\n3\n[1, 2]\nHigh Margin'),
#  Text(2123.121951219512, 919.9384615384615, '#150\nOffer Level 2_Desktop <= 0.5\n0.98\n100\n[58, 42]\nLow Margin'),
#  Text(2095.9024390243903, 752.6769230769232, '#151\n0.98\n46\n[27, 19]\nLow Margin'),
#  Text(2150.3414634146343, 752.6769230769232, '#152\n0.98\n54\n[31, 23]\nLow Margin'),
#  Text(2123.121951219512, 1087.2, '#153\n1.0\n54\n[26, 28]\nHigh Margin'),
#  Text(2150.3414634146343, 1254.4615384615386, '#154\n0.95\n8\n[3, 5]\nHigh Margin'),
#  Text(2177.560975609756, 1421.7230769230769, '#155\n0.96\n49\n[30, 19]\nLow Margin'),
#  Text(2204.780487804878, 1588.9846153846156, '#156\n0.0\n51\n[51, 0]\nLow Margin')]

# %%
clf = DecisionTreeClassifier(criterion='entropy',random_state=0)
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_prediction=clf.predict(X_test)

# %%
from mlxtend.evaluate import bias_variance_decomp

# %%
mse,bias, var = bias_variance_decomp(clf,                                     
                                     X_train, y_train, X_test, y_test, 
                                     loss='mse', num_rounds=200, random_seed=1)

# %%
from sklearn.metrics import accuracy_score
from sklearn import metrics

# %%
Accuracy = accuracy_score(y_test, y_prediction)
Precision = metrics.precision_score(y_test, y_prediction, average='macro')
Recall = metrics.recall_score(y_test, y_prediction, average='macro')
MAE = metrics.mean_absolute_error(y_test, y_prediction)
MSE = metrics.mean_squared_error(y_test, y_prediction)
RMSE = np.sqrt(metrics.mean_squared_error(y_test, y_prediction))
AvgBias = bias
AvgVar = var

results = pd.DataFrame([['Decision Tree', Accuracy, Precision, Recall, 
                         MAE, MSE, RMSE, AvgBias, AvgVar]],
                         columns = ['Model', 'Accuracy', 'Precision', 'Recall', 
                                    'MAE', 'MSE', 'RMSE','Avg Bias','Avg Variance'])

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
y_prediction = knn.predict(X_test)

# %%
mse,bias, var = bias_variance_decomp(knn, X_train, y_train, X_test, y_test, 
                                     loss='mse', 
                                     num_rounds=200, 
                                     random_seed=1)

# %%
Accuracy = accuracy_score(y_test, y_prediction)
Precision = metrics.precision_score(y_test, y_prediction, average='macro')
Recall = metrics.recall_score(y_test, y_prediction, average='macro')
MAE = metrics.mean_absolute_error(y_test, y_prediction)
MSE = metrics.mean_squared_error(y_test, y_prediction)
RMSE = np.sqrt(metrics.mean_squared_error(y_test, y_prediction))
AvgBias = bias
AvgVar = var

model_results = pd.DataFrame([['K-Nearest Neighbors (KNN)', Accuracy, Precision, Recall, 
                         MAE, MSE, RMSE, AvgBias, AvgVar]],
                         columns = ['Model', 'Accuracy', 'Precision', 'Recall', 
                                    'MAE', 'MSE', 'RMSE', 'Avg Bias', 'Avg Variance'])

results = results.append(model_results, ignore_index = True)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Create a Logistic Regression Object, perform Logistic Regression
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_prediction = log_reg.predict(X_test)

# %%
mse,bias, var = bias_variance_decomp(log_reg, 
                                     X_train, y_train, X_test, y_test, 
                                     loss='mse', 
                                     num_rounds=200, random_seed=1)

# %%
Accuracy = accuracy_score(y_test, y_prediction)
Precision = metrics.precision_score(y_test, y_prediction, average='macro')
Recall = metrics.recall_score(y_test, y_prediction, average='macro')
MAE = metrics.mean_absolute_error(y_test, y_prediction)
MSE = metrics.mean_squared_error(y_test, y_prediction)
RMSE = np.sqrt(metrics.mean_squared_error(y_test, y_prediction))
AvgBias = bias
AvgVar = var

model_results = pd.DataFrame([['Logistic Regression', Accuracy, Precision, Recall, 
                         MAE, MSE, RMSE, AvgBias, AvgVar]],
                         columns = ['Model', 'Accuracy', 'Precision', 'Recall', 
                                    'MAE', 'MSE', 'RMSE', 'Avg Bias', 'Avg Variance'])

results = results.append(model_results, ignore_index = True)

# %% [markdown]
# ## Naives Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()                     
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_prediction = model.predict(X_test)

# %%
mse,bias, var = bias_variance_decomp(model, 
                                     X_train, y_train, X_test, y_test, 
                                     loss='mse', 
                                     num_rounds=200, 
                                     random_seed=1)

# %%
Accuracy = accuracy_score(y_test, y_prediction)
Precision = metrics.precision_score(y_test, y_prediction, average='macro')
Recall = metrics.recall_score(y_test, y_prediction, average='macro')
MAE = metrics.mean_absolute_error(y_test, y_prediction)
MSE = metrics.mean_squared_error(y_test, y_prediction)
RMSE = np.sqrt(metrics.mean_squared_error(y_test, y_prediction))
AvgBias = bias
AvgVar = var

model_results = pd.DataFrame([['NAIVES BAYES', Accuracy, Precision, Recall, 
                         MAE, MSE, RMSE, AvgBias, AvgVar]],
                         columns = ['Model', 'Accuracy', 'Precision', 'Recall', 
                                    'MAE', 'MSE', 'RMSE', 'Avg Bias', 'Avg Variance'])

results = results.append(model_results, ignore_index = True)

# %% [markdown]
# ## Random Forest

# %%
from sklearn import ensemble

# %%
rf_clf=ensemble.RandomForestClassifier(n_estimators=500)
rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
y_prediction = rf_clf.predict(X_test)

# %%
mse,bias, var = bias_variance_decomp(rf_clf, 
                                     X_train, y_train, X_test, y_test, 
                                     loss='mse', 
                                     num_rounds=5, 
                                     random_seed=1)

# %%
Accuracy = accuracy_score(y_test, y_prediction)
Precision = metrics.precision_score(y_test, y_prediction, average='macro')
Recall = metrics.recall_score(y_test, y_prediction, average='macro')
MAE = metrics.mean_absolute_error(y_test, y_prediction)
MSE = metrics.mean_squared_error(y_test, y_prediction)
RMSE = np.sqrt(metrics.mean_squared_error(y_test, y_prediction))
AvgBias = bias
AvgVar = var

model_results = pd.DataFrame([['Random Forest', Accuracy, Precision, Recall, 
                         MAE, MSE, RMSE, AvgBias, AvgVar]],
                         columns = ['Model', 'Accuracy', 'Precision', 'Recall', 
                                    'MAE', 'MSE', 'RMSE', 'Avg Bias', 'Avg Variance'])

results = results.append(model_results, ignore_index = True)

# %% [markdown]
# ## Vector Machine

# %%
from sklearn.svm import SVC

# %%
svc_clf = SVC(probability=True, kernel='linear')
svc_clf.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %%
y_prediction = svc_clf.predict(X_test)

# %%
mse,bias, var = bias_variance_decomp(svc_clf, 
                                     X_train, y_train, X_test, y_test, 
                                     loss='mse', 
                                     num_rounds=5, 
                                     random_seed=1)

# %%
Accuracy = accuracy_score(y_test, y_prediction)
Precision = metrics.precision_score(y_test, y_prediction, average='macro')
Recall = metrics.recall_score(y_test, y_prediction, average='macro')
MAE = metrics.mean_absolute_error(y_test, y_prediction)
MSE = metrics.mean_squared_error(y_test, y_prediction)
RMSE = np.sqrt(metrics.mean_squared_error(y_test, y_prediction))
AvgBias = bias
AvgVar = var

model_results = pd.DataFrame([['Vector Machine', Accuracy, Precision, Recall, 
                         MAE, MSE, RMSE, AvgBias, AvgVar]],
                         columns = ['Model', 'Accuracy', 'Precision', 'Recall', 
                                    'MAE', 'MSE', 'RMSE', 'Avg Bias', 'Avg Variance'])

results = results.append(model_results, ignore_index = True)

# %%
results
# Out:
#                        Model  Accuracy  Precision    Recall         MAE  \
# 0              Decision Tree  0.704587   0.621852  0.564786   16.141284
# 1  K-Nearest Neighbors (KNN)  0.640367   0.611289  0.629643   61.645872
# 2        Logistic Regression  0.725688   0.670369  0.587783   12.857798
# 3               NAIVES BAYES  0.565138   0.646707  0.656571  102.034862
# 4              Random Forest  0.708257   0.629929  0.566516   14.972477
# 5             Vector Machine  0.718349   0.811755  0.529462    0.747706
#
#         MSE      RMSE    Avg Bias  Avg Variance
# 0  0.295413  0.543519  335.208294      0.053289
# 1  0.359633  0.599694  271.388116      0.171799
# 2  0.274312  0.523748  353.096410      0.020629
# 3  0.434862  0.659441  607.223461      0.026137
# 4  0.291743  0.540133  356.853945      0.036771
# 5  0.281651  0.530708  327.759633      0.041835

# %%
# SVM seems to be a better model based on the above results. Will continue to use the same to redict.

# %%
#The rest of the work book is submitted as part of Assignment 24.

# %% [markdown]
# ## K-Fold Validation

# %%
classifier = SVC(random_state = 0, kernel = 'linear', probability= True)
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True, random_state=0)

# %%
from sklearn.model_selection import cross_val_score

# %%
accuracies = cross_val_score(estimator=classifier, 
                             X=X_train, 
                             y=y_train,
                             cv=10)
accuracies.mean()
accuracies.std()
# Out:
# 0.006321641306545264

# %%
print("SVM (Linear) Accuracy: %0.3f (+/- %0.3f)" % (accuracies.mean(), accuracies.std() * 2))
# Out:
# SVM (Linear) Accuracy: 0.729 (+/- 0.013)

# %%
from sklearn.metrics import confusion_matrix

# %%
#Confusion Matrix
cm = confusion_matrix(y_test, y_prediction) # rows = truth, cols = prediction
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)
sns.heatmap(df_cm, annot=True, fmt='g')
# Out:
# <AxesSubplot:>

# %%
X_train = X_train_sc
X_test = X_test_sc

# %%
# Analyzing Coefficients
pd.concat([pd.DataFrame(X_train.columns, columns = ["features"]),
           pd.DataFrame(np.transpose(classifier.coef_), columns = ["coef"])
           ],axis = 1)
# Out:
#                                     features      coef
# 0            Product Classification_Hardware -0.017589
# 1            Product Classification_Software  0.017589
# 2             Sales Channel Code_Distributor  0.000024
# 3            Sales Channel Code_END_CUSTOMER -0.000053
# 4        Sales Channel Code_Service Provider -0.000019
# 5                 Sales Channel Code_UNKNOWN  0.000047
# 6              Offer Level 1_Conference Room -0.121324
# 7               Offer Level 1_Control Center -0.039653
# 8           Offer Level 1_End Point solution -0.124280
# 9             Offer Level 1_Network Security -0.006490
# 10                      Offer Level 1_Others -0.058826
# 11                 Offer Level 1_Product One  0.494435
# 12                      Offer Level 2_ASN-NG  0.005152
# 13       Offer Level 2_Conference room Infra  0.075812
# 14      Offer Level 2_Contact Center License  0.019892
# 15      Offer Level 2_Control Center console  0.026412
# 16                     Offer Level 2_Desktop  0.082109
# 17                  Offer Level 2_IoT Device  0.099426
# 18                     Offer Level 2_License  0.055273
# 19            Offer Level 2_Non IOS Software  0.037520
# 20                      Offer Level 2_Others -0.236560
# 21     Offer Level 2_Product One - Perpetual -0.441832
# 22  Offer Level 2_Product One - Subscription -0.242791
# 23              Offer Level 2_Screen Systems  0.075642
# 24          Offer Level 2_Security & Routing  0.087280
# 25  Offer Level 2_Security & Routing License  0.034867
# 26            Offer Level 2_Security License -0.009449
# 27                      Offer Level 2_Switch  0.031172
# 28           Offer Level 2_Switching License  0.034405
# 29            Offer Level 2_Wireless License  0.037185

# %%
# Recursive Feature Elimination
from sklearn.feature_selection import RFE
from sklearn.svm import SVC

# %%
# Model to Test
classifier = SVC(random_state = 0, kernel = 'linear', probability= True)

# Select Best X Features
rfe = RFE(classifier, n_features_to_select=None)
rfe = rfe.fit(X_train, y_train)

# %%
# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False False False False False False  True False  True False False  True
#  False  True False False  True  True  True False  True  True  True  True
#   True  True False False  True  True]
# [ 8 10 15 13 16 14  1  3  1 11  4  1 12  1  6  7  1  1  1  5  1  1  1  1
#   1  1  9  2  1  1]

# %%
X_train.columns[rfe.support_]
# Out:
# Index(['Offer Level 1_Conference Room', 'Offer Level 1_End Point solution',
#        'Offer Level 1_Product One', 'Offer Level 2_Conference room Infra',
#        'Offer Level 2_Desktop', 'Offer Level 2_IoT Device',
#        'Offer Level 2_License', 'Offer Level 2_Others',
#        'Offer Level 2_Product One - Perpetual',
#        'Offer Level 2_Product One - Subscription',
#        'Offer Level 2_Screen Systems', 'Offer Level 2_Security & Routing',
#        'Offer Level 2_Security & Routing License',
#        'Offer Level 2_Switching License', 'Offer Level 2_Wireless License'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data=X_train[X_train.columns[rfe.support_]].corr(), annot=True, cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
# Fitting Model to the Training Set
classifier = SVC(random_state = 0, kernel = 'linear', probability= True)
classifier.fit(X_train[X_train.columns[rfe.support_]], y_train)
# Out:
# SVC(kernel='linear', probability=True, random_state=0)

# %%
y_predinction = classifier.predict(X_test[X_train.columns[rfe.support_]])

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %%
accuracy = accuracy_score(y_test, y_predinction)
precision = precision_score(y_test, y_predinction)
recall = recall_score(y_test, y_predinction)
f1_score = (2 * (precision * recall) / (precision + recall))

print("Accuracy:", Accuracy)
print("Precision:", Precision)
print("Recall:", Recall)
print("f1_score:", f1_score)
# Out:
# Accuracy: 0.718348623853211
# Precision: 0.8117551923731698
# Recall: 0.5294620412267471
# f1_score: 0.8325150027277687

# %%
cm = confusion_matrix(y_test,y_prediction)
sns.heatmap(data=cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
#Making the classification report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.06      0.12       325
#            1       0.71      1.00      0.83       765
#
#     accuracy                           0.72      1090
#    macro avg       0.81      0.53      0.47      1090
# weighted avg       0.77      0.72      0.62      1090

# %%
# Applying k-Fold Cross Validation (RFE)
classifier
# Out:
# SVC(kernel='linear', probability=True, random_state=0)

# %%
accuracies = cross_val_score(estimator = classifier,
                             X = X_train[X_train.columns[rfe.support_]],
                             y = y_train, cv = 10)

# %%
print("SVM RFE (Linear) Accuracy: %0.3f (+/- %0.3f)" % (accuracies.mean(), accuracies.std() * 2))
# Out:
# SVM RFE (Linear) Accuracy: 0.729 (+/- 0.013)

# %%
# Analyzing Coefficients
pd.concat([pd.DataFrame(X_train[X_train.columns[rfe.support_]].columns, columns = ["features"]),
           pd.DataFrame(np.transpose(classifier.coef_), columns = ["coef"])
           ],axis = 1)
# Out:
#                                     features          coef
# 0              Offer Level 1_Conference Room -6.356177e-04
# 1           Offer Level 1_End Point solution -3.549800e-04
# 2                  Offer Level 1_Product One  5.666782e-01
# 3        Offer Level 2_Conference room Infra  3.686948e-04
# 4                      Offer Level 2_Desktop  2.530286e-04
# 5                   Offer Level 2_IoT Device -6.039613e-14
# 6                      Offer Level 2_License  2.060760e-04
# 7                       Offer Level 2_Others -2.730735e-01
# 8      Offer Level 2_Product One - Perpetual -5.119080e-01
# 9   Offer Level 2_Product One - Subscription -2.696937e-01
# 10              Offer Level 2_Screen Systems  2.328951e-04
# 11          Offer Level 2_Security & Routing -4.085621e-14
# 12  Offer Level 2_Security & Routing License -4.263256e-14
# 13           Offer Level 2_Switching License  0.000000e+00
# 14            Offer Level 2_Wireless License  7.105427e-15

# %%
# Formatting Final Results
final_results = pd.DataFrame(y_test, columns = ['y'])
final_results['predicted'] = y_prediction
final_results = final_results[['y', 'predicted']].reset_index(drop=True)
final_results
# Out:
#       y  predicted
# 0     1          1
# 1     1          1
# 2     1          1
# 3     1          1
# 4     0          1
# ...  ..        ...
# 1085  0          1
# 1086  1          1
# 1087  1          1
# 1088  0          1
# 1089  1          1
#
# [1090 rows x 2 columns]

# %%
# Visuailze the prediction
sns.countplot(x='y', data=final_results, label='Count')
# Out:
# <AxesSubplot:xlabel='y', ylabel='count'>

# %% [markdown]
# ## Conclusion

# %%
# Based on the data set available and the model prediction, the products with High Margin will continue to 
#make High margins. As and more data is available the mdoels can be further tuned to predict accurate results

# %%
# The suggestion to the company is to continue to invest in the products that are currently meeitng the 
# margin targets
